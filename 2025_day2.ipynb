# %%
fp = '2025_day2_input.txt'

with open(fp, 'r') as file:
    input = file.readline()

sequence = input.split(',')

id_ranges = []

for vals in sequence:
    first_val, second_val = vals.split('-')
    id_ranges.append((int(first_val), int(second_val)))

# %%
def even_count_of_digits(id_code):
    if len(str(id_code)) % 2 == 0:
        return True

# %%
def is_invalid(id_code):
    if not even_count_of_digits(id_code):
        return False

    id_as_string = str(id_code)
    half_id_len = int(len(id_as_string)/2)

    if id_as_string[0:half_id_len] == id_as_string[half_id_len]:
        return True

    return False

# %%
test_id = str(123456)
print(len(test_id))
half_len = int(len(test_id)/2)

print(half_len)
print(test_id[0:half_len])
print(test_id[half_len:])
# Out:
# 6
# 3
# 123
# 456

# %%
print(id_ranges[2])

for i in range(id_ranges[2][0],id_ranges[2][1]):
    if is_invalid(i):
        print(i)
# Out:
# (189952, 274622)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       1 print(id_ranges[2])
#       3 for i in range(id_ranges[2][0],id_ranges[2][1]):
# ----> 4     if is_invalid(i):
#       5         print(i)
#
# Cell In[42], line 8, in is_invalid(id_code)
#       5 id_as_string = str(id_code)
#       6 half_id_len = int(len(id_as_string)/2)
# ----> 8 if id_code_as_string[0:half_id_len] == id_code_as_string[half_id_len]:
#       9     return True
#      11 return False
#
# NameError: name 'id_code_as_string' is not defined
